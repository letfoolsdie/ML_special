# %%
import numpy
numpy.__version__
# Out:
# '1.10.4'

# %%
import scipy
scipy.__version__
# Out:
# '0.17.0'

# %%
import pandas
pandas.__version__
# Out:
# u'0.17.1'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '1.5.1'
